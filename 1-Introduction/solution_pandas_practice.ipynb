# %% [markdown]
# <a href="https://colab.research.google.com/github/besherh/Machine-Learning-Course/blob/master/1-Introduction/solution_pandas_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({
   'col1': ['Item0', 'Item0', 'Item1', 'Item1'],
   'col2': ['Gold', 'Bronze', 'Gold', 'Silver'],
   'col3': [1, 2, np.nan, 4]
})

# %% [markdown]
# Previewing Data
# To preview the data and the metadata of a dataframe you can use the following functions:

# %%
# Displays the top 5 rows.
print(df.head())
# Out:
#     col1    col2  col3
# 0  Item0    Gold   1.0
# 1  Item0  Bronze   2.0
# 2  Item1    Gold   NaN
# 3  Item1  Silver   4.0

# %%
# displays the last rows

print(df.tail)
# Out:
# <bound method NDFrame.tail of     col1    col2  col3
# 0  Item0    Gold   1.0
# 1  Item0  Bronze   2.0
# 2  Item1    Gold   NaN
# 3  Item1  Silver   4.0>

# %%
# The number of columns

print(len(df))
# Out:
# 4

# %% [markdown]
# #Sorting
#
# sort values by col1, then col2 in ascending order

# %%
#sort values


df.sort_values(by=['col2', 'col1'], ascending=True)
# Out:
#     col1    col2  col3
# 1  Item0  Bronze   2.0
# 0  Item0    Gold   1.0
# 2  Item1    Gold   NaN
# 3  Item1  Silver   4.0

# %% [markdown]
# # Selecting/Querying
# Individual columns can be selected with the [] operator or directly as attributes:
# # Selects only the column named 'col1';
# # Select two columns col1,col2

# %%
#select columns
df[['col1', 'col2']]
# Out:
#     col1    col2
# 0  Item0    Gold
# 1  Item0  Bronze
# 2  Item1    Gold
# 3  Item1  Silver

# %% [markdown]
# You can also select by absolute coordinates/position in the frame. Indices are zero based:
#
# # Selects second row
# # Selects rows 1-to-3

# %%
df.iloc[1:3]
# Out:
#     col1    col2  col3
# 1  Item0  Bronze   2.0
# 2  Item1    Gold   NaN

# %% [markdown]
# # Query by a single column value
# df[df.col3 > 0]
#
# # Query by a single column, if it is in a list of predefined values
# df[df['col2'].isin(['Gold', 'Silver'])]
#
# # A conjunction query using two columns
# df[(df['col3'] > 0) & (df['col2'] == 'Silver')]
#
# # A disjunction query using two columns
# df[(df['col3'] > 0) | (df['col2'] == 'Silver')]
#
# # A query checking the textual content of the cells
# df[df.col2.str.contains('ilver')]

# %%
#use the code from above cell to see the results of each query
df[df.col3 > 0]
df[(df['col3'] > 0) | (df['col2'] == 'Silver')]
df[df.col2.str.contains('ilver')]
# Out:
#     col1    col2  col3
# 3  Item1  Silver   4.0

# %%
df[df['col2'].isin(['Gold', 'Silver'])]
# Out:
#     col1    col2  col3
# 0  Item0    Gold   1.0
# 2  Item1    Gold   NaN
# 3  Item1  Silver   4.0

# %%
df[df.col2.str.contains('ilver')]
# Out:
#     col1    col2  col3
# 3  Item1  Silver   4.0

# %% [markdown]
# #Modifying Data Frames
#
# # Modifies the cell at 1,1, assign vaue 'Bronze again'
#
#
# # change the values in col3 to 'HelloPD'
#
# # Removes all rows with any missing values.

# %%
#your code here
df.loc[:,'col3'] = ['HelloPD'] * len(df)

# %% [markdown]
# #Basic plotting

# %%
#run the following code to create a new data frame
plot_df = pd.DataFrame({
    'col1': [1, 3, 2, 4],
    'col2': [3, 6, 5, 1],
    'col3': [4, 7, 6, 2],
})

plot_df
# Out:
#    col1  col2  col3
# 0     1     3     4
# 1     3     6     7
# 2     2     5     6
# 3     4     1     2

# %%
#use plot function to plot p
plot_df.plot()

# %%
#plot bar chart for plot_df
# Use kind='hbar' for horizontal bars, and stacked=True to stack the groups
plot_df.plot(kind='bar')
